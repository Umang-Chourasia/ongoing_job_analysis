# %%
import pandas as pd
import numpy as np
import ast
import re
import ast

# %%
df = pd.read_csv('company_EDA.csv')

# %%
# df.rename(columns={'required_skill': 'skills'}, inplace=True)

# %%
# import ast

# df['skills'] = df['skills'].apply(ast.literal_eval)

# %%
# df_exploded = df.explode('skills')
# df_exploded

# %%
# skills = df_exploded['skills'].unique().tolist()

# %%
# with open("skills.txt", "w", encoding="utf-8") as f:
#     for skill in skills:
#         f.write(skill + "\n")

# %%
# skill_group_map = {
#     # 🔹 Programming / Languages
#     'python': 'python',

#     # 🔹 SQL & Databases
#     'mysql': 'sql',
#     'postgresql': 'sql',
#     'sql server': 'sql',
#     'oracle sql': 'sql',
#     'sql database': 'sql',
#     'sql': 'sql',

#     # 🔹 Excel / BI
#     'excel': 'excel',
#     'advanced excel': 'excel',
#     'ms excel': 'excel',

#     'power bi': 'power bi',
#     'powerbi': 'power bi',
#     'tableau': 'tableau',

#     # 🔹 Data / ML
#     'machine learning': 'machine learning',
#     'artificial intelligence': 'machine learning',
#     'deep learning': 'machine learning',

#     'statistics': 'statistics',
#     'statistical analysis': 'statistics',

#     # 🔹 Libraries
#     'pandas': 'pandas',
#     'numpy': 'numpy',

#     # 🔹 Big Data
#     'spark': 'spark',
#     'pyspark': 'spark',
#     'hadoop': 'big data',

#     # 🔹 Cloud
#     'aws': 'aws',
#     'amazon web services': 'aws',
#     'azure': 'cloud',
#     'microsoft azure': 'cloud',
#     'gcp': 'cloud',

#     # 🔹 Visualization / Analytics
#     'data visualization': 'power bi',
#     'business intelligence': 'bi',

#     # 🔹 DevOps / Tools
#     'docker': 'devops',
#     'kubernetes': 'devops',

#     # 🔹 Security (you have a LOT of this)
#     'cyber security': 'security',
#     'information security': 'security',
#     'network security': 'security',
#     'endpoint security': 'security',
#     'cloud security': 'security',

#     # 🔹 Networking
#     'networking': 'networking',
#     'tcp': 'networking',
#     'dns': 'networking'
# }

# %%
# df_exploded['skills'] = df_exploded['skills'].apply(
#     lambda x: skill_group_map.get(x, x)
# )

# %%
df['has_sql'].value_counts()
# Out:
# has_sql
# 0    97062
# 1    75396
# Name: count, dtype: int64

# %%
# df_exploded.to_csv('company_EDA.csv', index = False)
